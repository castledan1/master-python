# %%
"""
Multilayer Perceptron
Dr. Carlos Villaseñor
"""

# Packages
import numpy as np

def linear(z, derivative=False):
    a = z
    if derivative:
        da = 1
        return a, da
    return a


def sigmoid(z, derivative=False):
    a = 1/(1+np.exp(-z))
    if derivative:
        da = a * (1 - a)
        return a, da
    return a


def tanh(z, derivative=False):
    a = np.tanh(z)
    if derivative:
        da = (1 - a) * (1 + a)
        return a, da
    return a


def relu(z, derivative=False):
    a = z * (z >= 0)
    if derivative:
        da = np.array(z >= 0, dtype=float)
        return a, da
    return a

class MLP:

    def __init__(self, layers_dims, 
                 hidden_activation=relu,
                 output_activation=sigmoid,
                 learning_rate=0.1):

        # Instance Attributes
        self.L = len(layers_dims) - 1
        self.w = [None] * (self.L + 1)
        self.b = [None] * (self.L + 1)
        self.f = [None] * (self.L + 1)
        self.layers = layers_dims
        self.eta = learning_rate

        # Initialize weights
        for l in range(1, self.L + 1):
            self.w[l] = -1 + 2 * np.random.rand(layers_dims[l], layers_dims[l-1])
            self.b[l] = -1 + 2 * np.random.rand(layers_dims[l], 1)
            
            if l == self.L:
                self.f[l] = output_activation
            else:
                self.f[l] = hidden_activation
                

    def predict(self, X):
        a = np.asanyarray(X)
        for l in range(1, self.L + 1):
            z = np.dot(self.w[l], a) + self.b[l]
            a = self.f[l](z)
        return a

    def fit(self, X, Y, epochs=100):

        # Number of samples
        P = X.shape[1]

        #Gradient Descent
        for _ in range(epochs):
            for p in range(P):

                # Initialize activations and their derivatives
                a = [None] * (self.L + 1)
                da = [None] * (self.L + 1)
                lg = [None] * (self.L + 1)
                
                # Propagation
                a[0] = X[:, p].reshape(self.layers[0], 1)
                for l in range(1, self.L + 1):
                    z = np.dot(self.w[l], a[l-1]) + self.b[l]
                    a[l], da[l] = self.f[l](z, derivative=True)

                # Backpropagation
                for l in range(self.L, 0, -1):
                    # Calculate local gradient (lg)
                    if l == self.L:
                        lg[l] = (Y[:, p] - a[l]) * da[l]
                    else:
                        lg[l] = np.dot(self.w[l + 1].T, lg[l+1]) * da[l]
                        
                # Update parameters
                for l in range(1, self.L + 1):
                    self.w[l] += self.eta * np.dot(lg[l], a[l - 1].T)
                    self.b[l] += self.eta * lg[l]

# %%
import matplotlib.pyplot as plt

def MLP_binary_classification_2d(X,Y,net):
    plt.figure()
    for i in range(X.shape[1]):
        if Y[0,i]==0:
            plt.plot(X[0,i], X[1,i], '.r')
        else:
            plt.plot(X[0,i], X[1,i], '.b')
    xmin, ymin=np.min(X[0,:])-0.5, np.min(X[1,:])-0.5
    xmax, ymax=np.max(X[0,:])+0.5, np.max(X[1,:])+0.5
    xx, yy = np.meshgrid(np.linspace(xmin,xmax,100), 
                         np.linspace(ymin,ymax,100))
    data = [xx.ravel(), yy.ravel()]
    zz = net.predict(data)
    zz = zz.reshape(xx.shape)
    plt.contourf(xx,yy,zz, alpha=0.8, 
                 cmap=plt.cm.RdBu)
    plt.xlim([xmin,xmax])
    plt.ylim([ymin,ymax])
    plt.grid()
    plt.show()

# %% [markdown]
# Problema 1: Compuerta XOR

# %%
from google.colab import files
import pandas as pd

# %%
X = np.array([[0, 0, 1, 1],
            [0, 1, 0, 1]])
Y = np.array([[1, 0, 0, 1]])

# %%
net = MLP((2,100,1), learning_rate=0.8)
print(net.predict(X))
MLP_binary_classification_2d(X,Y,net)
# Out:
# [[0.15809552 0.38922089 0.5915941  0.69985911]]

# %%
net.fit(X, Y)
print(net.predict(X))
MLP_binary_classification_2d(X,Y,net)
# Out:
# [[0.95902423 0.0380395  0.04199218 0.96251085]]

# %% [markdown]
# 2.- Moons

# %%
uploaded = files.upload()
# Out:
#      <input type="file" id="files-0c779208-ab2b-490f-955b-02e807bb57ef" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-0c779208-ab2b-490f-955b-02e807bb57ef">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving blobs.csv to blobs.csv
# Saving circles.csv to circles.csv
# Saving moons.csv to moons (1).csv

# %%
def print_result(fileName, isTrained):
  dataset = pd.read_csv(fileName)
  X = np.asanyarray(dataset.drop(columns=['y'])).T
  Y = np.asanyarray(dataset[['y']]).T 

  net = MLP((2,100,1), learning_rate=0.2)
  net.predict(X)

  if( isTrained ):
    net.fit(X, Y)
  
  net.predict(X)
  MLP_binary_classification_2d(X,Y,net)

# %%
# MOONS
X1 = np.asanyarray(fMoons.drop(columns=['y'])).T
Y1 = np.asanyarray(fMoons[['y']]).T
# BLOBS
X2 = np.asanyarray(fBlobs.drop(columns=['y'])).T
Y2 = np.asanyarray(fBlobs[['y']]).T.ravel()
# CIRCLES
X3 = np.asanyarray(fCircles.drop(columns=['y'])).T
Y3 = np.asanyarray(fCircles[['y']]).T.ravel()

# %%
print(X1.shape)
print(Y1.shape)
# Out:
# (2, 1000)
# (1, 1000)

# %%
nMoons = MLP((2,100,1), learning_rate=0.2)
nMoons.predict(X1)
MLP_binary_classification_2d(X1,Y1,nMoons)

# %%
nMoons.fit(X1, Y1)

# %%
MLP_binary_classification_2d(X1,Y1,nMoons)

# %%
print_result("moons (1).csv", False)

# %%
print_result("moons (1).csv", True)

# %%
print_result("blobs.csv", False)

# %%
print_result("blobs.csv", True)

# %%
print_result("circles.csv", False)

# %%
print_result("circles.csv", True)
